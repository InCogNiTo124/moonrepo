# %%
import sympy
import numpy as np
import scipy

e = sympy.E

# WolframAlpha + Gemini
coefficients = [
    0,  # x^0
    e,  # x^1
    0,  # x^2
    e**3 / 6,  # x^3
    -e**4 / 24,  # x^4
    e**5 / 15,  # x^5
    -13 * e**6 / 360,  # x^6
    97 * e**7 / 2520,  # x^7
    -571 * e**8 / 20160,  # x^8
    1217 * e**9 / 45360,  # x^9
    -3391 * e**10 / 151200  # x^10
]
coefs = [float(t.evalf()) if hasattr(t, 'evalf') else t for t in coefficients]

EPS = 0.02
delta = float((1/e).evalf())
errors = []
for deg_numer in range(1, 5):
    for deg_denom in range(1, 5):
        try:
            p, q = scipy.interpolate.pade(coefs, deg_numer, deg_denom)
        except:
            continue
        f = lambda x: (-math.log(-math.log(x)) - p(x-delta)/q(x-delta))**2  # squared error
        error = scipy.integrate.quad(f, EPS, 1-EPS, limit=100)[0] ** 0.5  # sqrt of integral
        errors.append((abs(error), (deg_numer, deg_denom)))

errors.sort()
print(errors[:3])
# Out:
# [(0.05273774642270674, (4, 1)), (0.06859734330880154, (4, 4)), (0.0706887022917013, (2, 3))]
# /tmp/ipykernel_132676/274416827.py:33: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   error = scipy.integrate.quad(f, EPS, 1-EPS, limit=100)[0] ** 0.5  # sqrt of integral

# %%
EPS = 0.02
errors = []
for deg_numer in range(1, 5):
    for deg_denom in range(1, 5):
        try:
            p, q = scipy.interpolate.pade(coefs, deg_numer, deg_denom)
        except:
            continue
        f = lambda x: (-math.log(-math.log(x)) - p(x-delta)/q(x-delta))**2
        error = scipy.integrate.quad(f, EPS, 1-EPS, limit=100)[0] ** 0.5
        errors.append((abs(error), (deg_numer, deg_denom)))

errors.sort()
print(errors[:3])
# Out:
# [(0.05273774642270674, (4, 1)), (0.06859734330880154, (4, 4)), (0.0706887022917013, (2, 3))]
# /tmp/ipykernel_132676/674264814.py:10: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   error = scipy.integrate.quad(f, EPS, 1-EPS, limit=100)[0] ** 0.5

# %%
p, q = scipy.interpolate.pade(coefs, 4, 1)

# %%
p
# Out:
# poly1d([2.71828183, 0.        ])

# %%
q
# Out:
# poly1d([-2.12326139,  0.83689737, -1.23150935, -0.        ,  1.        ])

# %%
float(((-e**2)/6).evalf())
# Out:
# -1.231509349821775

# %%
[-7*e**4/180,e**3/24,-e**2/6, 1]
# Out:
# [-7*exp(4)/180, exp(3)/24, -exp(2)/6, 1]
